# %% [markdown]
# ## **Code for Customization :**

# %%
# !pip install gensim --upgrade
# !pip install keras --upgrade
# !pip install pandas --upgrade

# %%
# DataFrame
import pandas as pd

# Matplot
import matplotlib.pyplot as plt
# %matplotlib inline

from matplotlib.ticker import MaxNLocator
import matplotlib.gridspec as gridspec
import matplotlib.patches as mpatches

# Scikit-learn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.manifold import TSNE
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from sklearn.metrics import f1_score, accuracy_score


# Keras
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, Embedding, Flatten, Conv1D, MaxPooling1D, LSTM
from keras import utils
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

# nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import nltk
nltk.download('omw-1.4')

# Word2vec
import gensim
from gensim.test.utils import common_texts
from gensim.models import Word2Vec


# Utility
import string
import re
import numpy as np
import os
from collections import Counter
import logging
import time
import pickle
import itertools
import random
import datetime

# WordCloud
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from collections import Counter, defaultdict

# Warnings
import warnings 
warnings.filterwarnings('ignore')

# Set log
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Valer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Valer\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Valer\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Valer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\Valer\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %% [markdown]
# ### **Step - 1.2 :** *Importing Dataset*

# %%
df = pd.read_csv("Twitter_Data.csv")
df1 = df

# %%
df.head(5)
# Out:
#                                           clean_text  category
# 0  when modi promised “minimum government maximum...      -1.0
# 1  talk all the nonsense and continue all the dra...       0.0
# 2  what did just say vote for modi  welcome bjp t...       1.0
# 3  asking his supporters prefix chowkidar their n...       1.0
# 4  answer who among these the most powerful world...       1.0

# %%
df = df[df.category != 0.0]

# %% [markdown]
# **Замечание** Я убрал нейтральные комментарии т.к. я хотел выполнить разделение на позитивные/негативные комментарии

# %%
df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 107767 entries, 0 to 162979
# Data columns (total 2 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   clean_text  107765 non-null  object
#  1   category    107760 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.5+ MB

# %% [markdown]
# ## **Step - 2 :** *Data Pre-processing*

# %%
# Varaibles related to dataset
DATASET_COLUMNS = ["clean_text", "category"]
DATASET_ENCODING = "ISO-8859-1"
TRAIN_SIZE = 0.8

# Parameters for WORD2VEC
W2V_SIZE = 300
W2V_WINDOW = 7
W2V_EPOCH = 32
W2V_MIN_COUNT = 10

# Parameters related to KERAS
SEQUENCE_LENGTH = 300
EPOCHS = 8
BATCH_SIZE = 1024

# Variable specific to SENTIMENT
POSITIVE = "POSITIVE"
NEGATIVE = "NEGATIVE"
NEUTRAL = "NEUTRAL"
SENTIMENT_THRESHOLDS = (0.4, 0.7)

# Variables for Exporting purpose
KERAS_MODEL = "model.h5"
WORD2VEC_MODEL = "model.w2v"
TOKENIZER_MODEL = "tokenizer.pkl"
ENCODER_MODEL = "encoder.pkl"

# MISC

pd.options.display.max_columns = 250
pd.options.display.max_rows = 250

# %%
# Confirming presence of missing values in each variable
df.isnull().sum()
# Out:
# clean_text    2
# category      7
# dtype: int64

# %%
df.dropna(how='any', inplace=True) # Removed these rows as the count is small and will not affect overall modelling
df.isnull().sum()
# Out:
# clean_text    0
# category      0
# dtype: int64

# %% [markdown]
# ### **Step - 2.3 :** Label Encoding

# %%
decode_map = {-1.0: "NEGATIVE", 1.0: "POSITIVE"}
def decode_sentiment(label):
    return decode_map[int(label)]

# %%
# %%time
df.category = df.category.apply(lambda x: decode_sentiment(x))
# Out:
# CPU times: total: 62.5 ms
# Wall time: 78.4 ms

# %%
category_cnt = Counter(df.category)

plt.figure(figsize=(16,8))
plt.bar(category_cnt.keys(), category_cnt.values())
plt.title("Dataset labels distribuition")
# Out:
# Text(0.5, 1.0, 'Dataset labels distribuition')

# %% [markdown]
# ### **Step - 2.4 :** Text Manipulation and Structurization

# %%
stop_words = set(stopwords.words("english"))
stop_words.remove('not')
more_stopwords = {'one', 'br', 'Po', 'th', 'sayi', 'fo', 'Unknown'}
stop_words = stop_words.union(more_stopwords)
                 
stemmer = SnowballStemmer("english")

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)


def remove_emoji(text):
    emoji_pattern = re.compile(
        '['
        u'\U0001F600-\U0001F64F'  # emoticons
        u'\U0001F300-\U0001F5FF'  # symbols & pictographs
        u'\U0001F680-\U0001F6FF'  # transport & map symbols
        u'\U0001F1E0-\U0001F1FF'  # flags (iOS)
        u'\U00002702-\U000027B0'
        u'\U000024C2-\U0001F251'
        ']+',
        flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)


def remove_html(text):
    html = re.compile(r'^[^ ]<.*?>|&([a-z0-9]+|#[0-9]\"\'\“{1,6}|#x[0-9a-f]{1,6});[^A-Za-z0-9]+')
    return re.sub(html, '', text)


def remove_punct(text):
    table = str.maketrans('', '', string.punctuation)
    return text.translate(table)

def remove_quotes(text):
    quotes = re.compile(r'[^A-Za-z0-9\s]+')
    return re.sub(quotes, '', text)


# Applying helper functions

df['mod_text'] = df['clean_text'].apply(lambda x: remove_URL(x))
df['mod_text'] = df['mod_text'].apply(lambda x: remove_emoji(x))
df['mod_text'] = df['mod_text'].apply(lambda x: remove_html(x))
df['mod_text'] = df['mod_text'].apply(lambda x: remove_punct(x))
df['mod_text'] = df['mod_text'].apply(lambda x: remove_quotes(x))
df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...

# %%
# Tokenizing the tweet base texts.

df['tokenized'] = df['mod_text'].apply(word_tokenize)

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...

# %%
# Lower casing clean text.

df['lower'] = df['tokenized'].apply(
    lambda x: [word.lower() for word in x])

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...

# %%
# Removing stopwords.

df['stopwords_removed'] = df['lower'].apply(
    lambda x: [word for word in x if word not in stop_words])

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...

# %%
# Applying part of speech tags.

df['pos_tags'] = df['stopwords_removed'].apply(nltk.tag.pos_tag)

df.head()

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN


df['wordnet_pos'] = df['pos_tags'].apply(
    lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed  \
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...
#
#                                             pos_tags  \
# 0  [(modi, NNS), (promised, VBD), (minimum, JJ), ...
# 2  [(say, VB), (vote, NN), (modi, FW), (welcome, ...
# 3  [(asking, VBG), (supporters, NNS), (prefix, VB...
# 4  [(answer, NN), (among, IN), (powerful, JJ), (w...
# 8  [(upcoming, JJ), (election, NN), (india, NN), ...
#
#                                          wordnet_pos
# 0  [(modi, n), (promised, v), (minimum, a), (gove...
# 2  [(say, v), (vote, n), (modi, n), (welcome, a),...
# 3  [(asking, v), (supporters, n), (prefix, v), (c...
# 4  [(answer, n), (among, n), (powerful, a), (worl...
# 8  [(upcoming, a), (election, n), (india, n), (sa...

# %%
# Applying word lemmatizer.

wnl = WordNetLemmatizer()

df['lemmatized'] = df['wordnet_pos'].apply(
    lambda x: [wnl.lemmatize(word, tag) for word, tag in x])

df['lemmatized'] = df['lemmatized'].apply(
    lambda x: [word for word in x if word not in stop_words])

df['lemma_str'] = [' '.join(map(str, l)) for l in df['lemmatized']]

df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed  \
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...
#
#                                             pos_tags  \
# 0  [(modi, NNS), (promised, VBD), (minimum, JJ), ...
# 2  [(say, VB), (vote, NN), (modi, FW), (welcome, ...
# 3  [(asking, VBG), (supporters, NNS), (prefix, VB...
# 4  [(answer, NN), (among, IN), (powerful, JJ), (w...
# 8  [(upcoming, JJ), (election, NN), (india, NN), ...
#
#                                          wordnet_pos  \
# 0  [(modi, n), (promised, v), (minimum, a), (gove...
# 2  [(say, v), (vote, n), (modi, n), (welcome, a),...
# 3  [(asking, v), (supporters, n), (prefix, v), (c...
# 4  [(answer, n), (among, n), (powerful, a), (worl...
# 8  [(upcoming, a), (election, n), (india, n), (sa...
#
#                                           lemmatized  \
# 0  [modi, promise, minimum, government, maximum, ...
# 2  [say, vote, modi, welcome, bjp, tell, rahul, m...
# 3  [ask, supporter, prefix, chowkidar, name, modi...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, go, importan...
#
#                                            lemma_str
# 0  modi promise minimum government maximum govern...
# 2  say vote modi welcome bjp tell rahul main camp...
# 3  ask supporter prefix chowkidar name modi great...
# 4  answer among powerful world leader today trump...
# 8  upcoming election india saga go important pair...

# %%
print("Total Rows =", len(df.clean_text))
# Out:
# Total Rows = 107758

# %%
df.head()
# Out:
#                                           clean_text  category  \
# 0  when modi promised “minimum government maximum...  NEGATIVE
# 2  what did just say vote for modi  welcome bjp t...  POSITIVE
# 3  asking his supporters prefix chowkidar their n...  POSITIVE
# 4  answer who among these the most powerful world...  POSITIVE
# 8  with upcoming election india saga going import...  POSITIVE
#
#                                             mod_text  \
# 0  when modi promised minimum government maximum ...
# 2  what did just say vote for modi  welcome bjp t...
# 3  asking his supporters prefix chowkidar their n...
# 4  answer who among these the most powerful world...
# 8  with upcoming election india saga going import...
#
#                                            tokenized  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                                lower  \
# 0  [when, modi, promised, minimum, government, ma...
# 2  [what, did, just, say, vote, for, modi, welcom...
# 3  [asking, his, supporters, prefix, chowkidar, t...
# 4  [answer, who, among, these, the, most, powerfu...
# 8  [with, upcoming, election, india, saga, going,...
#
#                                    stopwords_removed  \
# 0  [modi, promised, minimum, government, maximum,...
# 2  [say, vote, modi, welcome, bjp, told, rahul, m...
# 3  [asking, supporters, prefix, chowkidar, names,...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, going, impor...
#
#                                             pos_tags  \
# 0  [(modi, NNS), (promised, VBD), (minimum, JJ), ...
# 2  [(say, VB), (vote, NN), (modi, FW), (welcome, ...
# 3  [(asking, VBG), (supporters, NNS), (prefix, VB...
# 4  [(answer, NN), (among, IN), (powerful, JJ), (w...
# 8  [(upcoming, JJ), (election, NN), (india, NN), ...
#
#                                          wordnet_pos  \
# 0  [(modi, n), (promised, v), (minimum, a), (gove...
# 2  [(say, v), (vote, n), (modi, n), (welcome, a),...
# 3  [(asking, v), (supporters, n), (prefix, v), (c...
# 4  [(answer, n), (among, n), (powerful, a), (worl...
# 8  [(upcoming, a), (election, n), (india, n), (sa...
#
#                                           lemmatized  \
# 0  [modi, promise, minimum, government, maximum, ...
# 2  [say, vote, modi, welcome, bjp, tell, rahul, m...
# 3  [ask, supporter, prefix, chowkidar, name, modi...
# 4  [answer, among, powerful, world, leader, today...
# 8  [upcoming, election, india, saga, go, importan...
#
#                                            lemma_str
# 0  modi promise minimum government maximum govern...
# 2  say vote modi welcome bjp tell rahul main camp...
# 3  ask supporter prefix chowkidar name modi great...
# 4  answer among powerful world leader today trump...
# 8  upcoming election india saga go important pair...

# %%
df_mod = df[["lemma_str", "category"]]
df_mod.head()
# Out:
#                                            lemma_str  category
# 0  modi promise minimum government maximum govern...  NEGATIVE
# 2  say vote modi welcome bjp tell rahul main camp...  POSITIVE
# 3  ask supporter prefix chowkidar name modi great...  POSITIVE
# 4  answer among powerful world leader today trump...  POSITIVE
# 8  upcoming election india saga go important pair...  POSITIVE

# %% [markdown]
# ### **Step - 2.4 :** Train-Test Split

# %%
df_train, df_test = train_test_split(df_mod, test_size=1-TRAIN_SIZE, random_state=42)
print("TRAIN size:", len(df_train))
print("TEST size:", len(df_test))
# Out:
# TRAIN size: 86206
# TEST size: 21552

# %% [markdown]
# ## **Step - 3 :** *Word Cloud Analysis*

# %%
def plot_wordcloud(text, mask, title, title_size, figure_size=(24.0,16.0), image_color=False):
    """ A function for creating wordcloud images """
    words = text
    allwords = []
    for wordlist in words:
        allwords += wordlist
    mostcommon = FreqDist(allwords).most_common(140)
    wordcloud = WordCloud(
                    background_color='white',
                    stopwords = stop_words,
                    max_words = 140,
                    max_font_size = 120, 
                    random_state = 42,
                    mask = mask,
    ).generate(str(mostcommon))        
    
    ########
    
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'green', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()

# %%
comments_mask = np.array(Image.open('comment.png'))
plot_wordcloud(df['lemmatized'], comments_mask,
               'Most Common Words',
               title_size=30)

# %% [markdown]
# *Word2Vec Analysis*

# %% [markdown]
# ### **Step - 4.1 :** Corpus Creation

# %%
# %%time
documents = [text.split() for text in df_train.lemma_str]
# Out:
# CPU times: total: 531 ms
# Wall time: 716 ms

# %% [markdown]
# ### **Step - 4.2 :** Word2Vec Model Creation

# %%
w2v_model = gensim.models.word2vec.Word2Vec(vector_size=W2V_SIZE, 
                                            window=W2V_WINDOW, 
                                            min_count=W2V_MIN_COUNT, 
                                            workers=8)
# Out:
# 2024-04-12 12:21:26,382 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=0, vector_size=300, alpha=0.025>', 'datetime': '2024-04-12T12:21:26.379601', 'gensim': '4.3.2', 'python': '3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'created'}

# %% [markdown]
# ### **Step - 4.3 :** Vocab Creation

# %%
w2v_model.build_vocab(documents)
# Out:
# 2024-04-12 12:21:28,880 : INFO : collecting all words and their counts
# 2024-04-12 12:21:28,880 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-04-12 12:21:28,979 : INFO : PROGRESS: at sentence #10000, processed 164830 words, keeping 18784 word types
# 2024-04-12 12:21:29,056 : INFO : PROGRESS: at sentence #20000, processed 328648 words, keeping 28233 word types
# 2024-04-12 12:21:29,124 : INFO : PROGRESS: at sentence #30000, processed 493344 words, keeping 36201 word types
# 2024-04-12 12:21:29,180 : INFO : PROGRESS: at sentence #40000, processed 657607 words, keeping 43101 word types
# 2024-04-12 12:21:29,262 : INFO : PROGRESS: at sentence #50000, processed 821081 words, keeping 49698 word types
# 2024-04-12 12:21:29,325 : INFO : PROGRESS: at sentence #60000, processed 985061 words, keeping 55768 word types
# 2024-04-12 12:21:29,395 : INFO : PROGRESS: at sentence #70000, processed 1149178 words, keeping 61465 word types
# 2024-04-12 12:21:29,474 : INFO : PROGRESS: at sentence #80000, processed 1315460 words, keeping 67096 word types
# 2024-04-12 12:21:29,514 : INFO : collected 70296 word types from a corpus of 1417640 raw words and 86206 sentences
# 2024-04-12 12:21:29,515 : INFO : Creating a fresh vocabulary
# 2024-04-12 12:21:29,610 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 retains 8353 unique words (11.88% of original 70296, drops 61943)', 'datetime': '2024-04-12T12:21:29.610569', 'gensim': '4.3.2', 'python': '3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'prepare_vocab'}
# 2024-04-12 12:21:29,610 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 leaves 1309789 word corpus (92.39% of original 1417640, drops 107851)', 'datetime': '2024-04-12T12:21:29.610569', 'gensim': '4.3.2', 'python': '3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'prepare_vocab'}
# 2024-04-12 12:21:29,702 : INFO : deleting the raw counts dictionary of 70296 items
# 2024-04-12 12:21:29,706 : INFO : sample=0.001 downsamples 39 most-common words
# 2024-04-12 12:21:29,708 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 1159345.6720406478 word corpus (88.5%% of prior 1309789)', 'datetime': '2024-04-12T12:21:29.708399', 'gensim': '4.3.2', 'python': '3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'prepare_vocab'}
# 2024-04-12 12:21:29,826 : INFO : estimated required memory for 8353 words and 300 dimensions: 24223700 bytes
# 2024-04-12 12:21:29,826 : INFO : resetting layer weights
# 2024-04-12 12:21:29,868 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-04-12T12:21:29.868892', 'gensim': '4.3.2', 'python': '3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'build_vocab'}

# %%
words = w2v_model.wv.key_to_index.keys()
vocab_size = len(words)
print("Vocab size", vocab_size)
# Out:
# Vocab size 8353

# %% [markdown]
# ### **Step - 4.4 :** Training Word2Vec Model

# %%
# %%time
w2v_model.train(documents, total_examples=len(documents), epochs=W2V_EPOCH)
# Out:
# 2024-04-12 12:21:38,274 : INFO : Word2Vec lifecycle event {'msg': 'training model with 8 workers on 8353 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=7 shrink_windows=True', 'datetime': '2024-04-12T12:21:38.274453', 'gensim': '4.3.2', 'python': '3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'train'}
# 2024-04-12 12:21:39,346 : INFO : EPOCH 0 - PROGRESS: at 61.36% examples, 710534 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:39,990 : INFO : EPOCH 0: training on 1417640 raw words (1159349 effective words) took 1.6s, 703336 effective words/s
# 2024-04-12 12:21:41,029 : INFO : EPOCH 1 - PROGRESS: at 58.56% examples, 673037 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:41,754 : INFO : EPOCH 1: training on 1417640 raw words (1159063 effective words) took 1.7s, 667640 effective words/s
# 2024-04-12 12:21:42,787 : INFO : EPOCH 2 - PROGRESS: at 60.00% examples, 687217 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:43,452 : INFO : EPOCH 2: training on 1417640 raw words (1159462 effective words) took 1.7s, 691471 effective words/s
# 2024-04-12 12:21:44,547 : INFO : EPOCH 3 - PROGRESS: at 53.63% examples, 619096 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:45,385 : INFO : EPOCH 3: training on 1417640 raw words (1159167 effective words) took 1.8s, 628530 effective words/s
# 2024-04-12 12:21:46,407 : INFO : EPOCH 4 - PROGRESS: at 52.23% examples, 601369 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:47,298 : INFO : EPOCH 4: training on 1417640 raw words (1159633 effective words) took 1.9s, 613525 effective words/s
# 2024-04-12 12:21:48,347 : INFO : EPOCH 5 - PROGRESS: at 57.87% examples, 662622 words/s, in_qsize 16, out_qsize 0
# 2024-04-12 12:21:49,137 : INFO : EPOCH 5: training on 1417640 raw words (1159240 effective words) took 1.8s, 644563 effective words/s
# 2024-04-12 12:21:50,165 : INFO : EPOCH 6 - PROGRESS: at 53.62% examples, 620783 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:51,006 : INFO : EPOCH 6: training on 1417640 raw words (1159158 effective words) took 1.8s, 629287 effective words/s
# 2024-04-12 12:21:52,026 : INFO : EPOCH 7 - PROGRESS: at 55.74% examples, 644274 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:52,873 : INFO : EPOCH 7: training on 1417640 raw words (1159538 effective words) took 1.8s, 628134 effective words/s
# 2024-04-12 12:21:53,900 : INFO : EPOCH 8 - PROGRESS: at 51.52% examples, 595439 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:54,789 : INFO : EPOCH 8: training on 1417640 raw words (1159219 effective words) took 1.9s, 611796 effective words/s
# 2024-04-12 12:21:55,830 : INFO : EPOCH 9 - PROGRESS: at 52.93% examples, 610197 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:21:56,763 : INFO : EPOCH 9: training on 1417640 raw words (1158729 effective words) took 1.9s, 598148 effective words/s
# 2024-04-12 12:21:57,834 : INFO : EPOCH 10 - PROGRESS: at 47.23% examples, 525826 words/s, in_qsize 16, out_qsize 0
# 2024-04-12 12:21:58,833 : INFO : EPOCH 10 - PROGRESS: at 93.73% examples, 532124 words/s, in_qsize 9, out_qsize 0
# 2024-04-12 12:21:58,905 : INFO : EPOCH 10: training on 1417640 raw words (1159701 effective words) took 2.1s, 548767 effective words/s
# 2024-04-12 12:21:59,930 : INFO : EPOCH 11 - PROGRESS: at 45.80% examples, 531239 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:00,998 : INFO : EPOCH 11 - PROGRESS: at 83.99% examples, 470878 words/s, in_qsize 13, out_qsize 2
# 2024-04-12 12:22:01,317 : INFO : EPOCH 11: training on 1417640 raw words (1159203 effective words) took 2.4s, 486302 effective words/s
# 2024-04-12 12:22:02,354 : INFO : EPOCH 12 - PROGRESS: at 44.40% examples, 509858 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:03,384 : INFO : EPOCH 12 - PROGRESS: at 89.56% examples, 510247 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:03,591 : INFO : EPOCH 12: training on 1417640 raw words (1159425 effective words) took 2.2s, 517542 effective words/s
# 2024-04-12 12:22:04,654 : INFO : EPOCH 13 - PROGRESS: at 28.85% examples, 332287 words/s, in_qsize 16, out_qsize 0
# 2024-04-12 12:22:05,665 : INFO : EPOCH 13 - PROGRESS: at 73.39% examples, 420813 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:06,188 : INFO : EPOCH 13: training on 1417640 raw words (1159597 effective words) took 2.5s, 455995 effective words/s
# 2024-04-12 12:22:07,283 : INFO : EPOCH 14 - PROGRESS: at 42.28% examples, 463040 words/s, in_qsize 16, out_qsize 1
# 2024-04-12 12:22:08,281 : INFO : EPOCH 14 - PROGRESS: at 88.17% examples, 495621 words/s, in_qsize 14, out_qsize 1
# 2024-04-12 12:22:08,435 : INFO : EPOCH 14: training on 1417640 raw words (1159288 effective words) took 2.2s, 522720 effective words/s
# 2024-04-12 12:22:09,455 : INFO : EPOCH 15 - PROGRESS: at 46.52% examples, 537809 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:10,467 : INFO : EPOCH 15 - PROGRESS: at 93.03% examples, 535189 words/s, in_qsize 10, out_qsize 0
# 2024-04-12 12:22:10,591 : INFO : EPOCH 15: training on 1417640 raw words (1159059 effective words) took 2.1s, 541997 effective words/s
# 2024-04-12 12:22:11,644 : INFO : EPOCH 16 - PROGRESS: at 39.47% examples, 452365 words/s, in_qsize 16, out_qsize 0
# 2024-04-12 12:22:12,653 : INFO : EPOCH 16 - PROGRESS: at 85.40% examples, 488990 words/s, in_qsize 14, out_qsize 1
# 2024-04-12 12:22:12,949 : INFO : EPOCH 16: training on 1417640 raw words (1159023 effective words) took 2.3s, 498944 effective words/s
# 2024-04-12 12:22:14,024 : INFO : EPOCH 17 - PROGRESS: at 45.81% examples, 516335 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:15,027 : INFO : EPOCH 17 - PROGRESS: at 96.56% examples, 550682 words/s, in_qsize 5, out_qsize 1
# 2024-04-12 12:22:15,059 : INFO : EPOCH 17: training on 1417640 raw words (1159374 effective words) took 2.1s, 561482 effective words/s
# 2024-04-12 12:22:16,089 : INFO : EPOCH 18 - PROGRESS: at 48.67% examples, 562542 words/s, in_qsize 16, out_qsize 1
# 2024-04-12 12:22:16,980 : INFO : EPOCH 18: training on 1417640 raw words (1159497 effective words) took 1.9s, 612514 effective words/s
# 2024-04-12 12:22:18,076 : INFO : EPOCH 19 - PROGRESS: at 41.57% examples, 463757 words/s, in_qsize 16, out_qsize 4
# 2024-04-12 12:22:19,082 : INFO : EPOCH 19 - PROGRESS: at 86.80% examples, 491140 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:19,320 : INFO : EPOCH 19: training on 1417640 raw words (1159511 effective words) took 2.3s, 506427 effective words/s
# 2024-04-12 12:22:20,377 : INFO : EPOCH 20 - PROGRESS: at 48.69% examples, 559337 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:21,316 : INFO : EPOCH 20: training on 1417640 raw words (1159874 effective words) took 2.0s, 594153 effective words/s
# 2024-04-12 12:22:22,386 : INFO : EPOCH 21 - PROGRESS: at 54.34% examples, 610284 words/s, in_qsize 15, out_qsize 1
# 2024-04-12 12:22:23,214 : INFO : EPOCH 21: training on 1417640 raw words (1159002 effective words) took 1.9s, 621892 effective words/s
# 2024-04-12 12:22:24,263 : INFO : EPOCH 22 - PROGRESS: at 49.40% examples, 570023 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:25,269 : INFO : EPOCH 22 - PROGRESS: at 86.83% examples, 500599 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:25,569 : INFO : EPOCH 22: training on 1417640 raw words (1159196 effective words) took 2.3s, 502683 effective words/s
# 2024-04-12 12:22:26,631 : INFO : EPOCH 23 - PROGRESS: at 35.23% examples, 407553 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:27,629 : INFO : EPOCH 23 - PROGRESS: at 73.37% examples, 423507 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:28,133 : INFO : EPOCH 23: training on 1417640 raw words (1159378 effective words) took 2.5s, 462287 effective words/s
# 2024-04-12 12:22:29,165 : INFO : EPOCH 24 - PROGRESS: at 45.80% examples, 529373 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:30,166 : INFO : EPOCH 24 - PROGRESS: at 89.57% examples, 517652 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:30,363 : INFO : EPOCH 24: training on 1417640 raw words (1159297 effective words) took 2.2s, 526638 effective words/s
# 2024-04-12 12:22:31,402 : INFO : EPOCH 25 - PROGRESS: at 47.95% examples, 551351 words/s, in_qsize 14, out_qsize 1
# 2024-04-12 12:22:32,404 : INFO : EPOCH 25 - PROGRESS: at 95.85% examples, 552758 words/s, in_qsize 6, out_qsize 1
# 2024-04-12 12:22:32,442 : INFO : EPOCH 25: training on 1417640 raw words (1159284 effective words) took 2.0s, 566154 effective words/s
# 2024-04-12 12:22:33,482 : INFO : EPOCH 26 - PROGRESS: at 54.33% examples, 626829 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:34,412 : INFO : EPOCH 26: training on 1417640 raw words (1159454 effective words) took 1.9s, 599637 effective words/s
# 2024-04-12 12:22:35,451 : INFO : EPOCH 27 - PROGRESS: at 54.34% examples, 624404 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:36,302 : INFO : EPOCH 27: training on 1417640 raw words (1159510 effective words) took 1.9s, 624803 effective words/s
# 2024-04-12 12:22:37,357 : INFO : EPOCH 28 - PROGRESS: at 55.05% examples, 634313 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:38,188 : INFO : EPOCH 28: training on 1417640 raw words (1159589 effective words) took 1.8s, 630835 effective words/s
# 2024-04-12 12:22:39,236 : INFO : EPOCH 29 - PROGRESS: at 55.05% examples, 624038 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:40,083 : INFO : EPOCH 29: training on 1417640 raw words (1159463 effective words) took 1.9s, 619970 effective words/s
# 2024-04-12 12:22:41,141 : INFO : EPOCH 30 - PROGRESS: at 52.23% examples, 604590 words/s, in_qsize 15, out_qsize 0
# 2024-04-12 12:22:42,147 : INFO : EPOCH 30 - PROGRESS: at 96.55% examples, 557922 words/s, in_qsize 5, out_qsize 1
# 2024-04-12 12:22:42,182 : INFO : EPOCH 30: training on 1417640 raw words (1159561 effective words) took 2.0s, 568017 effective words/s
# 2024-04-12 12:22:43,224 : INFO : EPOCH 31 - PROGRESS: at 47.95% examples, 551209 words/s, in_qsize 14, out_qsize 0
# 2024-04-12 12:22:44,250 : INFO : EPOCH 31 - PROGRESS: at 93.73% examples, 534527 words/s, in_qsize 9, out_qsize 0
# 2024-04-12 12:22:44,334 : INFO : EPOCH 31: training on 1417640 raw words (1159445 effective words) took 2.1s, 545915 effective words/s
# 2024-04-12 12:22:44,344 : INFO : Word2Vec lifecycle event {'msg': 'training on 45364480 raw words (37099289 effective words) took 66.1s, 561610 effective words/s', 'datetime': '2024-04-12T12:22:44.344248', 'gensim': '4.3.2', 'python': '3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19045-SP0', 'event': 'train'}
# CPU times: total: 5min 26s
# Wall time: 1min 6s
# (37099289, 45364480)

# %% [markdown]
# ### **Step - 4.5 :** Word2Vec Model Testing

# %%
w2v_model.wv.most_similar("people")
# Out:
# [('trs', 0.47765031456947327),
#  ('party', 0.4568723142147064),
#  ('cadre', 0.4474663734436035),
#  ('ncp', 0.4058147370815277),
#  ('jds', 0.39621713757514954),
#  ('dmk', 0.39162254333496094),
#  ('congress', 0.38141560554504395),
#  ('coalition', 0.37792742252349854),
#  ('ally', 0.3762921392917633),
#  ('karnataka', 0.36151936650276184)]

# %% [markdown]
# ## *Sentiment Analysis using Deep-Learning Model*

# %% [markdown]
# **Long short-term memory (LSTM)** is an artificial recurrent neural network architecture used in the field of deep learning.
# Unlike standard feedforward neural networks, LSTM has feedback connections.
# It never keeps the entire data like standard recurrent neural network, lstm keeps short-term memory of data.
#
# ![](https://miro.medium.com/max/489/1*27JmK8VBdphpSCWNb4MhNA.png)

# %% [markdown]
# ### **Step - 5.1 :** Token and Vocab Creation

# %%
# %%time
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df_train.lemma_str)

vocab_size = len(tokenizer.word_index) + 1
print("Total words", vocab_size)
# Out:
# Total words 70291
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File <timed exec>:16
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\sparse\_compressed.py:1050, in _cs_matrix.toarray(self, order, out)
#    1048 if out is None and order is None:
#    1049     order = self._swap('cf')[0]
# -> 1050 out = self._process_toarray_args(order, out)
#    1051 if not (out.flags.c_contiguous or out.flags.f_contiguous):
#    1052     raise ValueError('Output array must be C or F contiguous')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\scipy\sparse\_base.py:1267, in _spbase._process_toarray_args(self, order, out)
#    1265     return out
#    1266 else:
# -> 1267     return np.zeros(self.shape, dtype=self.dtype, order=order)
#
# MemoryError: Unable to allocate 45.1 GiB for an array with shape (86206, 70291) and data type int64

# %% [markdown]
# ### **Step - 5.2 :** Label Encoding

# %%
labels = df_train.category.unique().tolist()
labels.append(NEUTRAL)
labels
# Out:
# ['POSITIVE', 'NEGATIVE', 'NEUTRAL']

# %%
encoder = LabelEncoder()
encoder.fit(df_train.category.tolist())

y_train = encoder.transform(df_train.category.tolist())
y_test = encoder.transform(df_test.category.tolist())

y_train = y_train.reshape(-1,1)
y_test = y_test.reshape(-1,1)

print("y_train",y_train.shape)
print("y_test",y_test.shape)
# Out:
# y_train (86206, 1)
# y_test (21552, 1)

# %%
print("x_train", x_train.shape)
print("y_train", y_train.shape)
print()
print("x_test", x_test.shape)
print("y_test", y_test.shape)
# Out:
# x_train (86206, 300)
# y_train (86206, 1)
#
# x_test (21552, 300)
# y_test (21552, 1)

# %%
y_train[:10]
# Out:
# array([[1],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1],
#        [0],
#        [1],
#        [0],
#        [1]])

# %% [markdown]
# ### **Step - 5.3 :** Embedding Layer Creation

# %%
embedding_matrix = np.zeros((vocab_size, W2V_SIZE))
for word, i in tokenizer.word_index.items():
  if word in w2v_model.wv:
    embedding_matrix[i] = w2v_model.wv[word]
print(embedding_matrix.shape)
# Out:
# (70297, 300)

# %%
embedding_layer = Embedding(vocab_size, W2V_SIZE, weights=[embedding_matrix], input_length=SEQUENCE_LENGTH, trainable=False)

# %% [markdown]
# ### **Step - 5.4 :** Model Creation - LSTM

# %%
model = Sequential()
model.add(embedding_layer)
model.add(Dropout(0.5))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

model.summary()
# Out:
# 2022-09-09 20:35:34.157329: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 300, 300)          21089100
# _________________________________________________________________
# dropout (Dropout)            (None, 300, 300)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, 100)               160400
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 21,249,601
# Trainable params: 160,501
# Non-trainable params: 21,089,100
# _________________________________________________________________

# %% [markdown]
# ### **Step - 5.5 :** Compiling Model

# %%
model.compile(loss='binary_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

# %% [markdown]
# ### **Step - 5.6 :** Callback Creation

# %%
callbacks = [ ReduceLROnPlateau(monitor='val_loss', patience=5, cooldown=0),
              EarlyStopping(monitor='val_acc', min_delta=1e-4, patience=5)]

# %% [markdown]
# ### **Step - 5.7 :** Model Training

# %%
# %%time
history = model.fit(x_train, y_train,
                    batch_size=BATCH_SIZE,
                    epochs=EPOCHS,
                    validation_split=0.1,
                    verbose=1,
                    callbacks=callbacks)
# Out:
# 2022-09-09 20:35:34.989033: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/8
# 76/76 [==============================] - 682s 9s/step - loss: 0.5846 - accuracy: 0.6830 - val_loss: 0.4888 - val_accuracy: 0.7563
# Epoch 2/8
# 76/76 [==============================] - 677s 9s/step - loss: 0.5114 - accuracy: 0.7396 - val_loss: 0.4408 - val_accuracy: 0.8037
# Epoch 3/8
# 76/76 [==============================] - 678s 9s/step - loss: 0.4824 - accuracy: 0.7603 - val_loss: 0.4124 - val_accuracy: 0.8134
# Epoch 4/8
# 76/76 [==============================] - 676s 9s/step - loss: 0.4510 - accuracy: 0.7822 - val_loss: 0.3966 - val_accuracy: 0.8284
# Epoch 5/8
# 76/76 [==============================] - 665s 9s/step - loss: 0.4303 - accuracy: 0.7962 - val_loss: 0.3861 - val_accuracy: 0.8303
# Epoch 6/8
# 76/76 [==============================] - 667s 9s/step - loss: 0.4151 - accuracy: 0.8058 - val_loss: 0.3745 - val_accuracy: 0.8368
# Epoch 7/8
# 76/76 [==============================] - 685s 9s/step - loss: 0.4033 - accuracy: 0.8143 - val_loss: 0.3684 - val_accuracy: 0.8441
# Epoch 8/8
# 76/76 [==============================] - 676s 9s/step - loss: 0.3938 - accuracy: 0.8188 - val_loss: 0.3587 - val_accuracy: 0.8469
# CPU times: user 4h 16min 35s, sys: 18min 13s, total: 4h 34min 48s
# Wall time: 1h 30min 4s

# %% [markdown]
# ### **Step - 5.8 :** Model Evaluation

# %%
# %%time
score = model.evaluate(x_test, y_test, batch_size=BATCH_SIZE)
print()
print("ACCURACY:",score[1])
print("LOSS:",score[0])
# Out:
# 22/22 [==============================] - 46s 2s/step - loss: 0.3565 - accuracy: 0.8500
#
# ACCURACY: 0.8500370979309082
# LOSS: 0.3564917743206024
# CPU times: user 2min 12s, sys: 13.1 s, total: 2min 25s
# Wall time: 46.3 s

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
 
epochs = range(len(acc))
 
plt.plot(epochs, acc, 'b', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
 
plt.figure()
 
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
 
plt.show()

# %% [markdown]
# ### **Step - 5.9 :** Prediction using Model

# %%
def decode_sentiment(score, include_neutral=True):
    if include_neutral:        
        label = NEUTRAL ### Whatever not coming in negative and positive sentiments has been considered as neutral
        if score <= SENTIMENT_THRESHOLDS[0]:
            label = NEGATIVE
        elif score >= SENTIMENT_THRESHOLDS[1]:
            label = POSITIVE

        return label
    else:
        return NEGATIVE if score < 0.5 else POSITIVE

# %%
def predict(clean_text, include_neutral=True):
    start_at = time.time()
    # Tokenize clean_text
    x_test = pad_sequences(tokenizer.texts_to_sequences([clean_text]), maxlen=SEQUENCE_LENGTH)
    # Predict
    score = model.predict([x_test])[0]
    # Decode sentiment
    label = decode_sentiment(score, include_neutral=include_neutral)

    return {"label": label, "score": float(score),
       "elapsed_time": time.time()-start_at}

# %%
predict("I love the music")
# Out:
# {'label': 'POSITIVE',
#  'score': 0.9900519847869873,
#  'elapsed_time': 0.5215010643005371}

# %%
predict("I have nothing to lose")
# Out:
# {'label': 'NEUTRAL',
#  'score': 0.5107656121253967,
#  'elapsed_time': 0.2791745662689209}

# %%
predict("Experience has been bad")
# Out:
# {'label': 'NEGATIVE',
#  'score': 0.0340648889541626,
#  'elapsed_time': 0.27196311950683594}

# %% [markdown]
# ### **Step - 5.10 :** Creating Confusion Matrix

# %%
# %%time
y_pred_1d = []
y_test_1d = list(df_test.category)
scores = model.predict(x_test, verbose=1, batch_size=8000)
y_pred_1d = [decode_sentiment(score, include_neutral=False) for score in scores]
# Out:
# 3/3 [==============================] - 34s 10s/step
# CPU times: user 1min 46s, sys: 10.5 s, total: 1min 57s
# Wall time: 34.3 s

# %%
def plot_confusion_matrix(cm, classes,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=30)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90, fontsize=22)
    plt.yticks(tick_marks, classes, fontsize=22)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label', fontsize=25)
    plt.xlabel('Predicted label', fontsize=25)

# %%
# %%time

cnf_matrix = confusion_matrix(y_test_1d, y_pred_1d)
plt.figure(figsize=(12,12))
plot_confusion_matrix(cnf_matrix, classes=df_train.category.unique(), title="Confusion matrix")
plt.show()
# Out:
# CPU times: user 336 ms, sys: 236 ms, total: 572 ms
# Wall time: 337 ms

# %% [markdown]
# ### **Step - 5.11 :** Classification Report

# %%
print(classification_report(y_test_1d, y_pred_1d))
# Out:
#               precision    recall  f1-score   support
#
#     NEGATIVE       0.85      0.65      0.74      7026
#     POSITIVE       0.85      0.94      0.89     14526
#
#     accuracy                           0.85     21552
#    macro avg       0.85      0.80      0.82     21552
# weighted avg       0.85      0.85      0.84     21552

# %% [markdown]
# ### **Step - 5.12 :** Accuracy Score

# %%
accuracy_score(y_test_1d, y_pred_1d)
# Out:
# 0.85003711952487

# %% [markdown]
# ### **Step - 5.13 :** Saving Model for future use

# %%
model.save(KERAS_MODEL)
w2v_model.save(WORD2VEC_MODEL)
pickle.dump(tokenizer, open(TOKENIZER_MODEL, "wb"), protocol=0)
pickle.dump(encoder, open(ENCODER_MODEL, "wb"), protocol=0)

# %% [markdown]
# ## **References:**

# %% [markdown]
# * **LSTM Overview** : [**Link**](https://www.analyticsvidhya.com/blog/2022/03/an-overview-on-long-short-term-memory-lstm/)
# * **Code Optimisation Techniques** : [**Link**](https://www.geeksforgeeks.org/optimization-tips-python-code/)
